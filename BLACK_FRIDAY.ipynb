# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bl_test=pd.read_csv(r"C:\Users\daved\Downloads\test.csv")

# %%
bl_test
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               1                   1
# ...

# %%
bl_train=pd.read_csv(r"C:\Users\daved\Downloads\train (2).csv")

# %%
bl_train
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
bl = bl_train.append(bl_test)
# Out:
# C:\Users\daved\AppData\Local\Temp\ipykernel_8052\3903570394.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   bl = bl_train.append(bl_test)

# %%
bl.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# dtype: int64

# %%
bl.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
bl.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 233594                         4+               1                   8
# 233595                         4+               1                   5
# 233596                         4+               1                   1
# 233597                         4+               0                  10
# 233598                         4+               1                   4
#
#         Product_Category_2  Product_Category_3  Purchase
# 233594                 NaN                 NaN       NaN
# ...

# %%
bl["Age"].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
bl["Gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
gender=pd.get_dummies(bl["Gender"],drop_first=True)
gender
# Out:
#         M
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
# ...    ..
# 233594  0
# 233595  0
# 233596  0
# 233597  0
# 233598  0
#
# [783667 rows x 1 columns]

# %%
gender=pd.get_dummies(bl["Gender"])
gender
# Out:
#         F  M
# 0       1  0
# 1       1  0
# 2       1  0
# 3       1  0
# 4       0  1
# ...    .. ..
# 233594  1  0
# 233595  1  0
# 233596  1  0
# 233597  1  0
# 233598  1  0
#
# [783667 rows x 2 columns]

# %%
bl.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# dtype: object

# %%
bl.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  7.836670e+05  783667.000000   783667.000000       783667.000000
# mean   1.003029e+06       8.079300        0.409777            5.366196
# std    1.727267e+03       6.522206        0.491793            3.878160
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001519e+06       2.000000        0.000000            1.000000
# 50%    1.003075e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       537685.000000       237858.000000  550068.000000
# mean             9.844506           12.668605    9263.968713
# std              5.089093            4.125510    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
bl.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
bl.drop(["User_ID"],axis=1,inplace=True)

# %%
bl
# Out:
#        Product_ID Gender    Age  Occupation City_Category  \
# 0       P00069042      F   0-17          10             A
# 1       P00248942      F   0-17          10             A
# 2       P00087842      F   0-17          10             A
# 3       P00085442      F   0-17          10             A
# 4       P00285442      M    55+          16             C
# ...           ...    ...    ...         ...           ...
# 233594  P00118942      F  26-35          15             B
# 233595  P00254642      F  26-35          15             B
# 233596  P00031842      F  26-35          15             B
# 233597  P00124742      F  46-50           1             C
# 233598  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
bl.drop(["City_Category"],axis=1,inplace=True)

# %%
bl["Stay_In_Current_City_Years"].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
bl["Stay_In_Current_City_Years"]=bl["Stay_In_Current_City_Years"].str.replace('+','')
# Out:
# C:\Users\daved\AppData\Local\Temp\ipykernel_8052\14176965.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   bl["Stay_In_Current_City_Years"]=bl["Stay_In_Current_City_Years"].str.replace('+','')

# %%
bl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783667 entries, 0 to 233598
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  783667 non-null  object
#  1   Gender                      783667 non-null  object
#  2   Age                         783667 non-null  object
#  3   Occupation                  783667 non-null  int64
#  4   Stay_In_Current_City_Years  783667 non-null  object
#  5   Marital_Status              783667 non-null  int64
#  6   Product_Category_1          783667 non-null  int64
#  7   Product_Category_2          537685 non-null  float64
#  8   Product_Category_3          237858 non-null  float64
#  9   Purchase                    550068 non-null  float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 65.8+ MB

# %%
bl["Stay_In_Current_City_Years"]=bl["Stay_In_Current_City_Years"].astype(int)
bl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783667 entries, 0 to 233598
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  783667 non-null  object
#  1   Gender                      783667 non-null  object
#  2   Age                         783667 non-null  object
#  3   Occupation                  783667 non-null  int64
#  4   Stay_In_Current_City_Years  783667 non-null  int32
#  5   Marital_Status              783667 non-null  int64
#  6   Product_Category_1          783667 non-null  int64
#  7   Product_Category_2          537685 non-null  float64
#  8   Product_Category_3          237858 non-null  float64
#  9   Purchase                    550068 non-null  float64
# dtypes: float64(3), int32(1), int64(3), object(3)
# memory usage: 62.8+ MB

# %%
bl.head(2)
# Out:
#   Product_ID Gender   Age  Occupation  Stay_In_Current_City_Years  \
# 0  P00069042      F  0-17          10                           2
# 1  P00248942      F  0-17          10                           2
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 NaN                 NaN
# 1               0                   1                 6.0                14.0
#
#    Purchase
# 0    8370.0
# 1   15200.0

# %%
sns.heatmap(bl.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
bl.shape
# Out:
# (783667, 10)

# %%
bl.duplicated().sum()
# Out:
# 35711

# %%
bl.plot()
# Out:
# <AxesSubplot:>

# %%
bl["Gender"]=bl["Gender"].map({"F":0,"M":2})

# %%
bl.head(5)
# Out:
#   Product_ID  Gender   Age  Occupation  Stay_In_Current_City_Years  \
# 0  P00069042       0  0-17          10                           2
# 1  P00248942       0  0-17          10                           2
# 2  P00087842       0  0-17          10                           2
# 3  P00085442       0  0-17          10                           2
# 4  P00285442       2   55+          16                           4
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 NaN                 NaN
# 1               0                   1                 6.0                14.0
# 2               0                  12                 NaN                 NaN
# 3               0                  12                14.0                 NaN
# 4               0                   8                 NaN                 NaN
#
#    Purchase
# 0    8370.0
# 1   15200.0
# 2    1422.0
# 3    1057.0
# 4    7969.0

# %%
bl["Age"].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
bl["Age"]=bl["Age"].map({'0-17':1, '18-25':2, '26-35':3, '46-50':4, '51-55':5, '36-45':6, '18-25':7})

# %%
bl.head(8)
# Out:
#   Product_ID  Gender  Age  Occupation  Stay_In_Current_City_Years  \
# 0  P00069042       0  1.0          10                           2
# 1  P00248942       0  1.0          10                           2
# 2  P00087842       0  1.0          10                           2
# 3  P00085442       0  1.0          10                           2
# 4  P00285442       2  NaN          16                           4
# 5  P00193542       2  3.0          15                           3
# 6  P00184942       2  4.0           7                           2
# 7  P00346142       2  4.0           7                           2
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 NaN                 NaN
# 1               0                   1                 6.0                14.0
# 2               0                  12                 NaN                 NaN
# ...

# %%
bl.tail()
# Out:
#        Product_ID  Gender  Age  Occupation  Stay_In_Current_City_Years  \
# 233594  P00118942       0  3.0          15                           4
# 233595  P00254642       0  3.0          15                           4
# 233596  P00031842       0  3.0          15                           4
# 233597  P00124742       0  4.0           1                           4
# 233598  P00316642       0  4.0           0                           4
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# 233594               1                   8                 NaN
# 233595               1                   5                 8.0
# 233596               1                   1                 5.0
# 233597               0                  10                16.0
# 233598               1                   4                 5.0
#
#         Product_Category_3  Purchase
# 233594                 NaN       NaN
# 233595                 NaN       NaN
# 233596                12.0       NaN
# ...

# %%
bl["Product_Category_2"].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
bl["Product_Category_2"].value_counts()
# Out:
# 8.0     91317
# 14.0    78834
# 2.0     70498
# 16.0    61687
# 15.0    54114
# 5.0     37165
# 4.0     36705
# 6.0     23575
# 11.0    20230
# 17.0    19104
# 13.0    15054
# 9.0      8177
# 12.0     7801
# 10.0     4420
# 3.0      4123
# 18.0     4027
# 7.0       854
# Name: Product_Category_2, dtype: int64

# %%
bl["Product_Category_3"]=bl["Product_Category_3"].fillna(bl["Product_Category_3"].mode()[0])
bl["Product_Category_2"]=bl["Product_Category_2"].fillna(bl["Product_Category_2"].mode()[0])

# %%
bl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783667 entries, 0 to 233598
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  783667 non-null  object
#  1   Gender                      783667 non-null  int64
#  2   Age                         753088 non-null  float64
#  3   Occupation                  783667 non-null  int64
#  4   Stay_In_Current_City_Years  783667 non-null  int32
#  5   Marital_Status              783667 non-null  int64
#  6   Product_Category_1          783667 non-null  int64
#  7   Product_Category_2          783667 non-null  float64
#  8   Product_Category_3          783667 non-null  float64
#  9   Purchase                    550068 non-null  float64
# dtypes: float64(4), int32(1), int64(4), object(1)
# memory usage: 62.8+ MB

# %%
bl.head(5)
# Out:
#   Product_ID  Gender  Age  Occupation  Stay_In_Current_City_Years  \
# 0  P00069042       0  1.0          10                           2
# 1  P00248942       0  1.0          10                           2
# 2  P00087842       0  1.0          10                           2
# 3  P00085442       0  1.0          10                           2
# 4  P00285442       2  NaN          16                           4
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 8.0                16.0
# 1               0                   1                 6.0                14.0
# 2               0                  12                 8.0                16.0
# 3               0                  12                14.0                16.0
# 4               0                   8                 8.0                16.0
#
#    Purchase
# 0    8370.0
# 1   15200.0
# 2    1422.0
# 3    1057.0
# 4    7969.0

# %%
plt.figure(figsize=(10,6))
sns.barplot("Age","Purchase",hue="Gender",data=bl)
# Out:
# C:\Users\daved\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Purchase'>

# %%
plt.figure(figsize=(10,6))
sns.barplot("Occupation","Purchase",hue="Gender",data=bl)
# Out:
# C:\Users\daved\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Occupation', ylabel='Purchase'>

# %%
plt.figure(figsize=(10,6))
sns.barplot("Product_Category_3","Purchase",hue="Gender",data=bl,palette="Set2")
# Out:
# C:\Users\daved\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product_Category_3', ylabel='Purchase'>

# %%
plt.figure(figsize=(10,6))
sns.barplot("Product_Category_2","Purchase",hue="Gender",data=bl,palette="Set1")
# Out:
# C:\Users\daved\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product_Category_2', ylabel='Purchase'>

# %%
plt.figure(figsize=(10,6))
sns.barplot("Product_Category_1","Purchase",hue="Gender",data=bl,palette="Set3")
# Out:
# C:\Users\daved\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Product_Category_1', ylabel='Purchase'>

# %%
bl_test=bl[bl["Purchase"].isnull()]

# %%
bl_test=bl

# %%
bl
# Out:
#        Product_ID  Gender  Age  Occupation  Stay_In_Current_City_Years  \
# 0       P00069042       0  1.0          10                           2
# 1       P00248942       0  1.0          10                           2
# 2       P00087842       0  1.0          10                           2
# 3       P00085442       0  1.0          10                           2
# 4       P00285442       2  NaN          16                           4
# ...           ...     ...  ...         ...                         ...
# 233594  P00118942       0  3.0          15                           4
# 233595  P00254642       0  3.0          15                           4
# 233596  P00031842       0  3.0          15                           4
# 233597  P00124742       0  4.0           1                           4
# 233598  P00316642       0  4.0           0                           4
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
bl_train=bl[bl["Purchase"].isnull()]

# %%
bl_train=bl

# %%
bl
# Out:
#        Product_ID  Gender  Age  Occupation  Stay_In_Current_City_Years  \
# 0       P00069042       0  1.0          10                           2
# 1       P00248942       0  1.0          10                           2
# 2       P00087842       0  1.0          10                           2
# 3       P00085442       0  1.0          10                           2
# 4       P00285442       2  NaN          16                           4
# ...           ...     ...  ...         ...                         ...
# 233594  P00118942       0  3.0          15                           4
# 233595  P00254642       0  3.0          15                           4
# 233596  P00031842       0  3.0          15                           4
# 233597  P00124742       0  4.0           1                           4
# 233598  P00316642       0  4.0           0                           4
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
bl.drop(["Product_ID"],axis=1,inplace=True)

# %%
bl
# Out:
#         Gender  Age  Occupation  Stay_In_Current_City_Years  Marital_Status  \
# 0            0  1.0          10                           2               0
# 1            0  1.0          10                           2               0
# 2            0  1.0          10                           2               0
# 3            0  1.0          10                           2               0
# 4            2  NaN          16                           4               0
# ...        ...  ...         ...                         ...             ...
# 233594       0  3.0          15                           4               1
# 233595       0  3.0          15                           4               1
# 233596       0  3.0          15                           4               1
# 233597       0  4.0           1                           4               0
# 233598       0  4.0           0                           4               1
#
# ...
