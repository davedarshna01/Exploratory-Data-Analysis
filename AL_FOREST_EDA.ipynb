# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
al=pd.read_csv(r"C:\Users\daved\Downloads\Algerian_forest_fires_dataset_UPDATE.csv",header=1)

# %%
al
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
al.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
al.tail()
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 241  6.5       fire
# 242    0   not fire
# 243  0.2   not fire
# 244  0.7   not fire
# 245  0.5  not fire

# %%
al.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 241    False
# 242    False
# 243    False
# 244    False
# 245    False
# Length: 246, dtype: bool

# %%
al.shape
# Out:
# (246, 14)

# %%
al.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
al.columns=al.columns.str.strip()

# %%
al.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4   RH           245 non-null    object
#  5   Ws           245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %%
al.describe()
# Out:
#         day month  year Temperature   RH   Ws Rain  FFMC  DMC   DC  ISI  BUI  \
# count   246   245   245         245  245  245  245   245  245  245  245  245
# unique   33     5     2          20   63   19   40   174  167  199  107  175
# top      01    07  2012          35   64   14    0  88.9  7.9    8  1.1    3
# freq      8    62   244          29   10   43  133     8    5    5    8    5
#
#         FWI  Classes
# count   245      244
# unique  128        9
# top     0.4  fire
# freq     12      131

# %% [markdown]
# # DATA CLEANING:

# %%
al.dtypes
# Out:
# day            object
# month          object
# year           object
# Temperature    object
# RH             object
# Ws             object
# Rain           object
# FFMC           object
# DMC            object
# DC             object
# ISI            object
# BUI            object
# FWI            object
# Classes        object
# dtype: object

# %%
al[~al.day.str.isnumeric()]
# Out:
#                                day  month  year  Temperature   RH   Ws   Rain  \
# 122  Sidi-Bel Abbes Region Dataset    NaN   NaN          NaN  NaN  NaN    NaN
# 123                            day  month  year  Temperature   RH   Ws  Rain
#
#      FFMC  DMC   DC  ISI  BUI  FWI    Classes
# 122   NaN  NaN  NaN  NaN  NaN  NaN        NaN
# 123  FFMC  DMC   DC  ISI  BUI  FWI  Classes

# %%
al1 = al.copy()

# %%
al1
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI       Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
al1 = al.drop(al.index[[122,123]])

# %%
al1
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI       Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
al1.shape
# Out:
# (244, 14)

# %%
al1[~al1.day.str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [day, month, year, Temperature, RH, Ws, Rain, FFMC, DMC, DC, ISI, BUI, FWI, Classes]
# Index: []

# %%
al1[['day','month','year','Temperature','RH','Ws']]=al1[['day','month','year','Temperature','RH','Ws']].astype(int)

# %%
al1["DC"]=al1["DC"].str.replace('14.6 9' , '14.69')
# Out:
# C:\Users\daved\AppData\Local\Temp\ipykernel_10216\4123482536.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   al1["DC"]=al1["DC"].str.replace('14.6 9' , '14.69')

# %%
al1["FWI"]=al1["FWI"].str.replace("fire" ,al1["FWI"].mode()[0])

# %%
al1[['Rain','FFMC','DMC','DC','ISI','BUI','FWI']]=al1[['Rain','FFMC','DMC','DC','ISI','BUI','FWI']].astype('float')

# %%
al1["Classes"].unique()
# Out:
# array(['not fire   ', 'fire   ', 'fire', 'fire ', 'not fire', 'not fire ',
#        'not fire     ', nan, 'not fire    '], dtype=object)

# %%
al1.Classes=al1.Classes.str.strip()

# %%
al1["Classes"].unique()
# Out:
# array(['not fire', 'fire', nan], dtype=object)

# %%
al1["Classes"]=al1["Classes"].str.replace("not fire","10")
al1["Classes"]=al1["Classes"].str.replace("fire","8")

# %%
al1["Classes"][160:170]
# Out:
# 162      8
# 163     10
# 164     10
# 165      8
# 166      8
# 167    NaN
# 168      8
# 169      8
# 170      8
# 171      8
# Name: Classes, dtype: object

# %%
al1.loc[167,"Classes"]=al1["Classes"].mode()[0]

# %%
al1["Classes"]=al1["Classes"].astype(int)

# %%
al1
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 241   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 242   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 243   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 244   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 245   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI  Classes
# ...

# %%
al1.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  244.000000  244.000000   244.0   244.000000  244.000000  244.000000
# mean    15.754098    7.500000  2012.0    32.172131   61.938525   15.504098
# std      8.825059    1.112961     0.0     3.633843   14.884200    2.810178
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.000000   14.000000
# 50%     16.000000    7.500000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.250000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  244.000000  244.000000  244.000000  244.000000  244.000000  244.000000
# mean     0.760656   77.887705   14.673361   49.288484    4.774180   16.664754
# ...

# %%
al1.corr()
# Out:
#                       day         month  year  Temperature        RH  \
# day          1.000000e+00  2.232788e-17   NaN     0.095772 -0.074209
# month        2.232788e-17  1.000000e+00   NaN    -0.059017 -0.037884
# year                  NaN           NaN   NaN          NaN       NaN
# Temperature  9.577222e-02 -5.901677e-02   NaN     1.000000 -0.654443
# RH          -7.420934e-02 -3.788419e-02   NaN    -0.654443  1.000000
# Ws           4.700086e-02 -4.144673e-02   NaN    -0.278132  0.236084
# Rain        -1.122654e-01  3.532207e-02   NaN    -0.326786  0.222968
# FFMC         2.240321e-01  1.557668e-02   NaN     0.677491 -0.645658
# DMC          4.915710e-01  6.817778e-02   NaN     0.483105 -0.405133
# DC           5.279300e-01  1.276691e-01   NaN     0.370511 -0.220344
# ISI          1.777266e-01  6.168011e-02   NaN     0.607551 -0.690637
# BUI          5.172292e-01  8.582162e-02   NaN     0.455504 -0.348587
# FWI          3.509095e-01  8.411895e-02   NaN     0.558800 -0.570483
# ...

# %% [markdown]
# # EDA

# %%
al1.hist(figsize=(25,20),color="g")
# Out:
# array([[<AxesSubplot:title={'center':'day'}>,
#         <AxesSubplot:title={'center':'month'}>,
#         <AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'Temperature'}>],
#        [<AxesSubplot:title={'center':'RH'}>,
#         <AxesSubplot:title={'center':'Ws'}>,
#         <AxesSubplot:title={'center':'Rain'}>,
#         <AxesSubplot:title={'center':'FFMC'}>],
#        [<AxesSubplot:title={'center':'DMC'}>,
#         <AxesSubplot:title={'center':'DC'}>,
#         <AxesSubplot:title={'center':'ISI'}>,
#         <AxesSubplot:title={'center':'BUI'}>],
#        [<AxesSubplot:title={'center':'FWI'}>,
#         <AxesSubplot:title={'center':'Classes'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# # BIVARIANT ANALYSIS:

# %%
sns.pairplot(al1)

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.heatmap(al1.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,15))
plt.suptitle("Analysis Of Numerical Features",fontsize=15,fontweight="bold",alpha=0.8,y=1.2)

for i in range(0, len(al1.columns)):
    plt.subplot(7, 3, i+1)
    sns.kdeplot(x=al1[al1.columns[i]],shade=True,color='r')
    plt.xlabel(al1.columns[i])
    plt.tight_layout()
# Out:
# C:\Users\daved\anaconda3\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
plt.scatter(al1["Classes"],al1["Temperature"])
plt.xlabel("fire(0) or Not fire(1)")
plt.ylabel("Temperature")
# Out:
# Text(0, 0.5, 'Temperature')

# %%
plt.scatter(al1["Rain"],al1["Temperature"])
plt.xlabel("Rain")
plt.ylabel("Temperature")
# Out:
# Text(0, 0.5, 'Temperature')

# %%
plt.scatter(al1["RH"],al1["Temperature"])
plt.xlabel("RH")
plt.ylabel("Temperature")
# Out:
# Text(0, 0.5, 'Temperature')

# %%
plt.scatter(al1["FFMC"],al1["Temperature"])
plt.xlabel("FFMC")
plt.ylabel("Temperature")
# Out:
# Text(0, 0.5, 'Temperature')

# %%
plt.scatter(al1["DC"],al1["Temperature"])
plt.xlabel("DC")
plt.ylabel("Temperature")
# Out:
# Text(0, 0.5, 'Temperature')

# %%
plt.scatter(al1["Rain"],al1["RH"])
plt.xlabel("Rain")
plt.ylabel("RH")
# Out:
# Text(0, 0.5, 'RH')

# %%
al1[al1.Temperature == (al1.Temperature.max())]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC   ISI  \
# 201   17      8  2012           42  24   9   0.0  96.0  30.3  76.4  15.7
#
#       BUI   FWI  Classes
# 201  30.4  24.0        8

# %%
al1[al1.Temperature == (al1.Temperature.min())]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC   DC  ISI  BUI  \
# 93     2      9  2012           22  86  15  10.1  30.5  0.7  7.0  0.0  1.1
# 105   14      9  2012           22  76  26   8.3  47.4  1.1  7.0  0.4  1.6
#
#      FWI  Classes
# 93   0.0       10
# 105  0.1       10

# %%
al1[al1.Rain == (al1.Rain.max())]
# Out:
#     day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC   DC  ISI  BUI  \
# 91   31      8  2012           28  80  21  16.8  52.5  8.7  8.7  0.6  8.3
#
#     FWI  Classes
# 91  0.3       10

# %%
al1[al1.RH == (al1.RH.min())]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC   ISI  \
# 196   12      8  2012           39  21  17   0.4  93.0  18.4  41.5  15.5
#
#       BUI   FWI  Classes
# 196  18.4  18.8        8

# %%
class_A=al1.Classes.value_counts(normalize=True)*100
class_A
# Out:
# 8     56.557377
# 10    43.442623
# Name: Classes, dtype: float64

# %%
classes_labels=["FIRE","NOT_FIRE"]
plt.figure(figsize=(10,8))
plt.pie(class_A,labels=classes_labels,autopct="%1.2f%%")
plt.title("pie chart of classes",fontsize=15)
plt.show()

# %%
al1
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 241   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 242   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 243   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 244   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 245   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI  Classes
# ...
